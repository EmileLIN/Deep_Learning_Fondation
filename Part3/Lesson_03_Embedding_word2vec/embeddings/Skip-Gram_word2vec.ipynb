# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
# look up the data
int_words[1:30]
# Out:
# [3080,
#  11,
#  5,
#  194,
#  1,
#  3133,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10571,
#  133,
#  0,
#  27349,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15067,
#  58112,
#  1,
#  0,
#  150,
#  854,
#  3580]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)

freqs = {word: count/total_count for word,count  in word_counts.items() }

prob_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

train_words = [word for word in int_words if random.random() < (1 - prob_drop[word])]

# %%
# train word

train_words[1:30]
# Out:
# [3133,
#  155,
#  10571,
#  27349,
#  854,
#  15067,
#  58112,
#  3580,
#  194,
#  10712,
#  1324,
#  454,
#  3672,
#  708,
#  1423,
#  7088,
#  44611,
#  186,
#  5233,
#  2621,
#  8983,
#  59,
#  6437,
#  4186,
#  6753,
#  7573,
#  1774,
#  566,
#  93]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    ran = np.random.randint(1, window_size+1)
    
    start = idx - ran if (idx - ran)>0 else 0
    stop = idx + ran
    
    selected_words = list(set(words[start : idx] + words[idx+1: stop+1]))
     
    return selected_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = "inputs")
    labels = tf.placeholder(tf.int32, [None, None], name = "labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200   # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed =tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w =  tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev= 0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6723 0.2831 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6289 0.2762 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5490 0.2706 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6195 0.2825 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5078 0.2901 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5406 0.2945 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5418 0.2992 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5453 0.3015 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4602 0.3079 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4200 0.3121 sec/batch
# Nearest to this: selden, griswold, stepdaughter, guarantors, tub, kabbalists, contralto, dodi,
# Nearest to four: retain, elliot, five, segovia, grizzly, mercader, sweaters, koblenz,
# Nearest to all: barn, cosa, relationships, rl, disclaimed, pawn, equinoctial, hear,
# Nearest to five: dimensions, four, oxide, vaulted, offend, carnivore, scantily, venezia,
# Nearest to known: aged, thursday, sabres, manatee, seeks, tema, glorioso, df,
# Nearest to will: intensional, afternoon, shellfish, palettes, local, privatisation, alveoli, kale,
# Nearest to for: endorsed, wilde, prevails, railways, panjabi, immigrating, hell, cryonics,
# Nearest to other: cormorants, strengthens, opportunity, gladly, shook, tim, lancaster, lautaro,
# Nearest to egypt: poetic, fouled, precipitates, gnumeric, isomers, videla, maharashtra, tri,
# Nearest to san: metohija, precambrian, dietmar, tamar, patricia, tacit, unrequited, panorama,
# Nearest to event: porsche, statues, renamed, jennifer, eldorado, imagining, faerie, nakano,
# Nearest to defense: publicised, van, enough, caray, flagging, trivalent, vayikra, entangle,
# Nearest to account: repels, kd, blackmailed, evergreen, habitual, nagai, tien, hardwood,
# Nearest to report: cai, betters, americana, degree, separateness, pitchers, inexperience, reins,
# Nearest to shows: gemologists, thereabouts, nigra, terraces, hangover, drilling, vilhelm, scifan,
# Nearest to know: dixie, percent, nuances, boleslaus, nand, ferrell, airplay, encyclopedia,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4592 0.3231 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3639 0.3146 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3020 0.3147 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1939 0.3143 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1604 0.3253 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1561 0.3235 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0950 0.3316 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0533 0.2919 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9863 0.3332 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9444 0.3397 sec/batch
# Nearest to this: selden, brackets, course, question, stepdaughter, thanks, be, cost,
# Nearest to four: retain, elliot, five, respectively, digits, grizzly, segovia, run,
# Nearest to all: relationships, barn, cosa, production, hear, few, pawn, rl,
# Nearest to five: dimensions, four, oxide, vaulted, offend, venezia, engelbart, ideals,
# Nearest to known: aged, seeks, thursday, laws, kurdistan, sound, cheaper, accept,
# Nearest to will: local, intensional, afternoon, shellfish, palettes, near, timed, alveoli,
# Nearest to for: endorsed, hell, political, host, o, prevails, railways, susceptible,
# Nearest to other: opportunity, cormorants, strengthens, lancaster, tim, gladly, abundance, scott,
# Nearest to egypt: poetic, precipitates, fouled, gnumeric, two, maharashtra, barbarians, videla,
# Nearest to san: metohija, precambrian, patricia, tamar, keypad, out, panorama, slang,
# Nearest to event: porsche, renamed, jennifer, imagining, episode, statues, thompson, recreate,
# Nearest to defense: enough, publicised, van, flagging, caray, trivalent, magus, bible,
# Nearest to account: repels, evergreen, habitual, kd, blackmailed, china, websites, tien,
# Nearest to report: degree, cai, americana, pitchers, betters, august, maeterlinck, trieste,
# Nearest to shows: gemologists, thereabouts, nigra, drilling, minority, liberty, border, underlying,
# Nearest to know: percent, dixie, encyclopedia, become, my, nuances, airplay, limbs,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9246 0.3446 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8990 0.3414 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8682 0.3456 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8559 0.3334 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8236 0.3342 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8179 0.3286 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7941 0.2971 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8050 0.3219 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7796 0.2864 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7719 0.3016 sec/batch
# Nearest to this: selden, tub, brackets, griswold, stepdaughter, course, cost, naming,
# Nearest to four: five, elliot, retain, skeptics, heights, respectively, pp, tolerating,
# Nearest to all: barn, relationships, cosa, spiritual, equinoctial, disclaimed, hear, pawn,
# Nearest to five: four, dimensions, seven, offend, venezia, vaulted, lombardi, oxide,
# Nearest to known: aged, thursday, seeks, cheaper, kurdistan, laws, df, sound,
# Nearest to will: intensional, palettes, local, afternoon, ea, shellfish, triggered, timed,
# Nearest to for: endorsed, hell, railways, wilde, prevails, political, algorithmic, host,
# Nearest to other: opportunity, cormorants, strengthens, shook, gladly, lancaster, abundance, regard,
# Nearest to egypt: poetic, precipitates, fouled, two, gnumeric, barbarians, maharashtra, tri,
# Nearest to san: metohija, precambrian, keypad, patricia, panorama, unrequited, slang, tamar,
# Nearest to event: renamed, porsche, imagining, statues, jennifer, intentional, episode, citizens,
# Nearest to defense: publicised, van, enough, flagging, trivalent, caray, vietnamese, aquarium,
# Nearest to account: habitual, evergreen, repels, blackmailed, tien, kd, nagai, inheriting,
# Nearest to report: degree, cai, americana, inexperience, betters, munitions, pitchers, reins,
# Nearest to shows: gemologists, nigra, thereabouts, authenticity, drilling, liberty, consent, underlying,
# Nearest to know: dixie, my, percent, nuances, become, encyclopedia, airplay, pipelines,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7704 0.3424 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7531 0.3464 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7174 0.3384 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7212 0.3348 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7359 0.3482 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7139 0.3446 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6861 0.3534 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7182 0.3496 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7138 0.3433 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6336 0.3420 sec/batch
# Nearest to this: tub, selden, griswold, brackets, kabbalists, recreated, rubenstein, stepdaughter,
# Nearest to four: five, elliot, two, retain, zero, tolerating, skeptics, heights,
# Nearest to all: barn, relationships, cosa, disclaimed, spiritual, pawn, equinoctial, biological,
# Nearest to five: four, seven, statesman, two, venezia, bartholomew, filmmaker, mesozoic,
# Nearest to known: aged, thursday, seeks, sabres, hanged, cheaper, engels, manatee,
# Nearest to will: intensional, palettes, ea, local, timed, privatisation, afternoon, shellfish,
# Nearest to for: endorsed, hell, railways, wilde, prevails, algorithmic, host, locks,
# Nearest to other: cormorants, opportunity, shook, aeronautics, lancaster, abundance, gladly, behaviours,
# Nearest to egypt: poetic, fouled, precipitates, isomers, two, barbarians, gnumeric, maharashtra,
# Nearest to san: metohija, precambrian, unrequited, keypad, dietmar, melvin, tamar, riordan,
# Nearest to event: imagining, porsche, jennifer, statues, renamed, jumbo, episode, nakano,
# Nearest to defense: publicised, van, flagging, enough, trivalent, overcomes, vietnamese, caray,
# Nearest to account: habitual, inheriting, tien, blackmailed, evergreen, overran, repels, nagai,
# Nearest to report: cai, degree, americana, inexperience, munitions, obscenity, reins, trieste,
# Nearest to shows: gemologists, nigra, thereabouts, authenticity, drilling, terraces, liberty, hangover,
# Nearest to know: nuances, my, dixie, become, pipelines, airplay, limbs, percent,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6726 0.3385 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6981 0.3093 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6115 0.3355 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6371 0.3382 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6304 0.3340 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6707 0.3034 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6000 0.2103 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5676 0.2827 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4958 0.2674 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5188 0.2953 sec/batch
# Nearest to this: selden, question, tub, stepdaughter, griswold, rubenstein, guarantors, be,
# Nearest to four: five, elliot, two, zero, pp, tolerating, heights, koblenz,
# Nearest to all: barn, relationships, cosa, disclaimed, spiritual, few, pawn, biological,
# Nearest to five: four, seven, two, statesman, filmmaker, venezia, bartholomew, zero,
# Nearest to known: aged, thursday, seeks, sabres, manatee, hanged, secretly, sect,
# Nearest to will: intensional, palettes, ea, privatisation, timed, afternoon, local, catamaran,
# Nearest to for: endorsed, hell, railways, immigrating, prevails, boac, wilde, host,
# Nearest to other: cormorants, aeronautics, opportunity, shook, alde, beans, gladly, abundance,
# Nearest to egypt: fouled, maharashtra, poetic, barbarians, isomers, gnumeric, precipitates, videla,
# Nearest to san: metohija, unrequited, agnes, melvin, precambrian, clashed, riordan, garter,
# Nearest to event: imagining, jennifer, statues, porsche, renamed, jumbo, episode, nakano,
# Nearest to defense: publicised, flagging, enough, van, overcomes, trivalent, vietnamese, caray,
# Nearest to account: habitual, inheriting, blackmailed, tien, nagai, kd, eckersley, apollonia,
# Nearest to report: cai, degree, americana, betters, inexperience, obscenity, reins, separateness,
# Nearest to shows: gemologists, nigra, thereabouts, authenticity, hangover, terraces, liberty, addressable,
# Nearest to know: nuances, my, dixie, become, airplay, pipelines, boleslaus, colourless,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5031 0.2681 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5055 0.2602 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4597 0.2573 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5057 0.2529 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4967 0.2609 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4839 0.2520 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4740 0.2661 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4159 0.2554 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4256 0.2669 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4150 0.2544 sec/batch
# Nearest to this: stepdaughter, rubenstein, selden, be, question, tub, griswold, guarantors,
# Nearest to four: five, zero, elliot, two, tolerating, est, koblenz, pp,
# Nearest to all: barn, relationships, cosa, spiritual, disclaimed, few, biological, louisiane,
# Nearest to five: four, seven, two, zero, venezia, deansgate, lombardi, statesman,
# Nearest to known: thursday, aged, sabres, seeks, sect, manatee, hanged, sound,
# Nearest to will: intensional, palettes, timed, ea, privatisation, afternoon, shellfish, interrupt,
# Nearest to for: endorsed, hell, platonism, boac, algorithmic, fifa, bloemfontein, wilde,
# Nearest to other: beans, cormorants, aeronautics, abundance, alde, opportunity, gladly, shook,
# Nearest to egypt: fouled, barbarians, maharashtra, poetic, ojibwe, videla, precipitates, circumscription,
# Nearest to san: metohija, unrequited, agnes, gutman, panorama, melvin, clashed, garter,
# Nearest to event: imagining, eldorado, porsche, mow, jennifer, faerie, sophocles, recreate,
# Nearest to defense: publicised, flagging, vietnamese, caray, trivalent, enough, overcomes, emmer,
# Nearest to account: habitual, inheriting, tien, blackmailed, nagai, apollonia, organelles, eckersley,
# Nearest to report: cai, americana, degree, betters, inexperience, reins, munitions, trieste,
# Nearest to shows: gemologists, nigra, hangover, addressable, authenticity, thereabouts, terraces, liberty,
# Nearest to know: my, nuances, become, sure, airplay, disoriented, dixie, assumes,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4498 0.2633 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4161 0.2617 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4598 0.2519 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4053 0.2599 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3875 0.2591 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4356 0.2622 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3971 0.2549 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3812 0.2603 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4180 0.2582 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3651 0.2682 sec/batch
# Nearest to this: question, rubenstein, tub, be, selden, predictors, stepdaughter, guarantors,
# Nearest to four: five, two, zero, elliot, three, pp, koblenz, tolerating,
# Nearest to all: barn, relationships, spiritual, cosa, disclaimed, few, louisiane, biological,
# Nearest to five: four, seven, two, zero, deansgate, lombardi, venezia, six,
# Nearest to known: sabres, aged, thursday, sect, seeks, manatee, edwin, hanged,
# Nearest to will: intensional, palettes, timed, afternoon, privatisation, ea, interrupt, might,
# Nearest to for: endorsed, hell, boac, bloemfontein, algorithmic, opal, primitives, wilde,
# Nearest to other: abundance, undigested, gladly, aeronautics, pasteurization, opportunity, beans, ovum,
# Nearest to egypt: barbarians, maharashtra, fouled, ojibwe, videla, hereford, tian, balearic,
# Nearest to san: metohija, unrequited, gutman, agnes, ford, beira, swann, melvin,
# Nearest to event: imagining, porsche, mow, recreate, eldorado, faerie, uralic, situational,
# Nearest to defense: publicised, flagging, emmer, vietnamese, caray, chapterhouse, emiliano, trivalent,
# Nearest to account: habitual, inheriting, blackmailed, tien, apollonia, religion, eckersley, nagai,
# Nearest to report: cai, americana, degree, reins, betters, munitions, trieste, obscenity,
# Nearest to shows: gemologists, hangover, nigra, addressable, thereabouts, authenticity, liberty, terraces,
# Nearest to know: my, nuances, become, disoriented, you, airplay, sure, assumes,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3771 0.2886 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3973 0.2807 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3489 0.2705 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3637 0.2761 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4093 0.2835 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3756 0.2791 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3714 0.2795 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3912 0.2753 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3299 0.2850 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3360 0.2785 sec/batch
# Nearest to this: rubenstein, tub, be, question, predictors, selden, course, surround,
# Nearest to four: five, two, zero, three, elliot, one, est, pp,
# Nearest to all: barn, spiritual, relationships, cosa, few, louisiane, disclaimed, saraswati,
# Nearest to five: four, seven, two, zero, six, deansgate, lombardi, million,
# Nearest to known: sabres, sect, aged, manatee, edwin, glorioso, characterises, thursday,
# Nearest to will: palettes, intensional, timed, ea, afternoon, privatisation, that, pegging,
# Nearest to for: endorsed, hell, boac, algorithmic, immigrating, bloemfontein, host, developers,
# Nearest to other: abundance, undigested, behaviours, beans, gladly, alde, pasteurization, aeronautics,
# Nearest to egypt: barbarians, maharashtra, balearic, hereford, fouled, ojibwe, two, videla,
# Nearest to san: metohija, ford, unrequited, swann, agnes, dietmar, beira, gutman,
# Nearest to event: imagining, porsche, mow, faerie, eldorado, uralic, equivalency, aros,
# Nearest to defense: publicised, flagging, emmer, emiliano, trivalent, shortcuts, carlyle, caray,
# Nearest to account: habitual, inheriting, blackmailed, apollonia, tien, religion, eckersley, reichskanzler,
# Nearest to report: cai, americana, oecd, degree, connelly, reins, betters, stauffenberg,
# Nearest to shows: hangover, gemologists, nigra, addressable, authenticity, thereabouts, cruijff, liberty,
# Nearest to know: my, nuances, disoriented, you, sure, become, assumes, tell,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3407 0.2858 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2961 0.2769 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3684 0.2825 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3970 0.2782 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3819 0.2743 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2956 0.2881 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3260 0.2737 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3375 0.2812 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2324 0.2699 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3287 0.2827 sec/batch
# Nearest to this: tub, rubenstein, question, predictors, selden, be, surround, cancel,
# Nearest to four: five, two, zero, three, one, elliot, six, est,
# Nearest to all: barn, spiritual, cosa, disclaimed, louisiane, few, relationships, saraswati,
# Nearest to five: four, seven, two, zero, six, one, lombardi, statesman,
# Nearest to known: sabres, manatee, glorioso, edwin, thursday, sect, aged, incidences,
# Nearest to will: palettes, intensional, timed, privatisation, afternoon, replied, ea, that,
# Nearest to for: endorsed, bloemfontein, hell, boac, opal, developers, fifa, wilde,
# Nearest to other: abundance, gladly, beans, undigested, behaviours, aeronautics, alde, sagas,
# Nearest to egypt: barbarians, balearic, ojibwe, fouled, maharashtra, tian, hereford, two,
# Nearest to san: metohija, unrequited, swann, gutman, dietmar, agnes, mwh, melvin,
# Nearest to event: imagining, aros, porsche, faerie, eldorado, mow, jennifer, equivalency,
# Nearest to defense: publicised, emmer, flagging, shortcuts, emiliano, vietnamese, fumimaro, tribunals,
# Nearest to account: habitual, inheriting, blackmailed, apollonia, tien, transfiguration, eckersley, religion,
# Nearest to report: cai, americana, oecd, connelly, degree, august, inexperience, reins,
# Nearest to shows: hangover, gemologists, nigra, addressable, authenticity, cruijff, cincinnati, thereabouts,
# Nearest to know: my, disoriented, you, nuances, sure, become, tell, razor,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2953 0.2794 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2885 0.2860 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3395 0.1250 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2610 0.2893 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2509 0.2752 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1958 0.4642 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2202 0.4593 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2470 0.4430 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2128 0.4546 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1793 0.4663 sec/batch
# Nearest to this: tub, rubenstein, surround, cancel, be, thanks, contralto, selden,
# Nearest to four: five, two, zero, three, one, elliot, six, pp,
# Nearest to all: barn, spiritual, cosa, disclaimed, few, louisiane, relationships, saraswati,
# Nearest to five: four, seven, two, zero, six, one, deansgate, july,
# Nearest to known: sabres, manatee, sect, characterises, glorioso, edwin, pork, tema,
# Nearest to will: palettes, intensional, timed, afternoon, privatisation, that, down, replied,
# Nearest to for: endorsed, bloemfontein, fifa, hell, boac, architectures, pointers, compulsion,
# Nearest to other: beans, most, abundance, gladly, undigested, cormorants, alde, shook,
# Nearest to egypt: barbarians, balearic, sultan, romans, ojibwe, fouled, syria, discernment,
# Nearest to san: metohija, unrequited, dietmar, swann, mwh, ford, panorama, beira,
# Nearest to event: imagining, porsche, aros, eldorado, faerie, mow, jennifer, equivalency,
# Nearest to defense: publicised, tribunals, flagging, shortcuts, caray, emmer, vietnamese, emiliano,
# Nearest to account: inheriting, habitual, blackmailed, transfiguration, apollonia, gell, tien, god,
# Nearest to report: oecd, connelly, cai, august, quarterly, summits, americana, reins,
# Nearest to shows: hangover, nigra, gemologists, cruijff, authenticity, addressable, thereabouts, dhamma,
# Nearest to know: my, disoriented, you, nuances, sure, tell, airplay, faithfully,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2499 0.4529 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2473 0.4628 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2218 0.4640 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1327 0.4445 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1732 0.4573 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1658 0.4679 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1555 0.4594 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1832 0.4352 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2003 0.4471 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2073 0.4524 sec/batch
# Nearest to this: be, tub, whims, question, rubenstein, cancel, fragmenting, recite,
# Nearest to four: five, two, zero, three, one, six, elliot, est,
# Nearest to all: spiritual, barn, cosa, relationships, louisiane, disclaimed, few, recursion,
# Nearest to five: four, two, seven, zero, six, one, three, deansgate,
# Nearest to known: sabres, characterises, manatee, tema, sect, pork, edwin, glorioso,
# Nearest to will: palettes, timed, intensional, that, me, everything, privatisation, replied,
# Nearest to for: endorsed, bloemfontein, compulsion, algorithmic, opal, hell, boac, fifa,
# Nearest to other: most, abundance, beans, undigested, gladly, walnuts, behaviours, alde,
# Nearest to egypt: barbarians, balearic, ojibwe, sultan, romans, syria, persepolis, fouled,
# Nearest to san: metohija, swann, unrequited, diego, dietmar, beira, panorama, ford,
# Nearest to event: imagining, aros, porsche, mow, eldorado, equivalency, jennifer, recreate,
# Nearest to defense: publicised, tribunals, shortcuts, begining, carlyle, attorneys, caray, chapterhouse,
# Nearest to account: inheriting, habitual, blackmailed, transfiguration, gell, religion, panini, tien,
# Nearest to report: oecd, quarterly, cai, connelly, boards, august, americana, munitions,
# Nearest to shows: hangover, gemologists, nigra, addressable, cruijff, authenticity, thereabouts, dhamma,
# Nearest to know: my, you, sure, disoriented, nuances, tell, airplay, become,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1783 0.4543 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2197 0.4659 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1804 0.4571 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1466 0.4840 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1785 0.4534 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2261 0.4444 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1859 0.4448 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1893 0.4516 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1237 0.4529 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1797 0.4844 sec/batch
# Nearest to this: be, tub, lysenkoism, rubenstein, question, mingled, cancel, thanks,
# Nearest to four: five, two, zero, three, one, six, pp, digits,
# Nearest to all: barn, spiritual, louisiane, cosa, disclaimed, relationships, saraswati, few,
# Nearest to five: four, seven, two, zero, six, one, three, eight,
# Nearest to known: sabres, edwin, characterises, glorioso, tema, manatee, incidences, elmo,
# Nearest to will: palettes, intensional, timed, that, everything, local, myself, down,
# Nearest to for: endorsed, fifa, compulsion, boac, opal, hell, bloemfontein, algorithmic,
# Nearest to other: most, abundance, gladly, beans, undigested, walnuts, behaviours, shook,
# Nearest to egypt: barbarians, balearic, ojibwe, discernment, sultan, two, rossellini, trench,
# Nearest to san: metohija, panorama, zeeuws, swann, diego, unrequited, mwh, ford,
# Nearest to event: imagining, aros, mow, porsche, equivalency, eldorado, faerie, situational,
# Nearest to defense: publicised, tribunals, shortcuts, begining, attorneys, carlyle, caray, emmer,
# Nearest to account: inheriting, habitual, blackmailed, transfiguration, gell, panini, pallium, apollonia,
# Nearest to report: oecd, quarterly, boards, connelly, august, cai, authorities, www,
# Nearest to shows: hangover, nigra, gemologists, authenticity, dhamma, interpolated, cruijff, teleology,
# Nearest to know: my, you, sure, disoriented, tell, nuances, airplay, become,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1944 0.4537 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1630 0.4674 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1692 0.4760 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2095 0.4531 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1401 0.4333 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1520 0.4472 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1688 0.4856 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1313 0.4893 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2043 0.4832 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1929 0.4669 sec/batch
# Nearest to this: be, tub, fragmenting, recite, lysenkoism, thanks, mingled, whims,
# Nearest to four: five, two, zero, three, one, six, seven, eight,
# Nearest to all: barn, spiritual, louisiane, cosa, disclaimed, few, members, god,
# Nearest to five: four, seven, two, zero, six, one, three, july,
# Nearest to known: sabres, sect, glorioso, edwin, characterises, tema, manatee, incidences,
# Nearest to will: timed, intensional, palettes, that, myself, me, afternoon, replied,
# Nearest to for: endorsed, fifa, bloemfontein, compulsion, supreme, opal, wilde, hell,
# Nearest to other: most, gladly, beans, sagas, australians, rallying, bangs, exalt,
# Nearest to egypt: barbarians, ojibwe, two, discernment, balearic, rossellini, trench, syria,
# Nearest to san: metohija, diego, swann, panorama, dietmar, ford, zeeuws, unrequited,
# Nearest to event: imagining, aros, mow, jennifer, porsche, faerie, equivalency, eldorado,
# Nearest to defense: publicised, tribunals, attorneys, kazakhstan, disputes, pullback, shortcuts, caray,
# Nearest to account: inheriting, habitual, blackmailed, transfiguration, apollonia, pallium, tien, panini,
# Nearest to report: oecd, authorities, quarterly, connelly, august, boards, cai, munitions,
# Nearest to shows: hangover, nigra, cincinnati, authenticity, gemologists, dhamma, hulk, purim,
# Nearest to know: my, you, sure, tell, disoriented, nuances, faithfully, airplay,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2067 0.4629 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1735 0.4717 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1318 0.4520 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1530 0.4829 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0482 0.4380 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1493 0.4650 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1429 0.4539 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1431 0.4388 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1560 0.0701 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1514 0.4276 sec/batch
# Nearest to this: be, tub, whims, fragmenting, cancel, thanks, selden, align,
# Nearest to four: five, two, zero, three, one, six, years, koblenz,
# Nearest to all: spiritual, barn, disclaimed, cosa, louisiane, saraswati, god, few,
# Nearest to five: four, seven, two, zero, six, one, three, nine,
# Nearest to known: sabres, sect, tema, characterises, edwin, manatee, glorioso, pork,
# Nearest to will: timed, intensional, palettes, that, privatisation, afternoon, myself, replied,
# Nearest to for: compulsion, fifa, endorsed, opal, bloemfontein, algorithmic, quartile, other,
# Nearest to other: most, beans, for, undigested, gladly, bangs, walnuts, abundance,
# Nearest to egypt: barbarians, ojibwe, discernment, trench, two, balearic, rossellini, hereford,
# Nearest to san: metohija, diego, zeeuws, swann, dietmar, mwh, panorama, beira,
# Nearest to event: imagining, aros, mow, porsche, jennifer, faerie, equivalency, malamud,
# Nearest to defense: publicised, tribunals, attorneys, caray, warheads, pullback, shortcuts, disputes,
# Nearest to account: inheriting, habitual, blackmailed, transfiguration, gpmg, karnstein, apollonia, pallium,
# Nearest to report: oecd, connelly, quarterly, august, cai, boards, munitions, authorities,
# Nearest to shows: hangover, nigra, hulk, cincinnati, gemologists, dhamma, dwyer, purim,
# Nearest to know: my, you, sure, tell, disoriented, faithfully, nuances, airplay,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0869 0.4406 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0887 0.4456 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0799 0.4377 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0455 0.4333 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0960 0.4348 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0352 0.4359 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0659 0.4531 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0978 0.4192 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1248 0.2574 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0437 0.2612 sec/batch
# Nearest to this: be, tub, cancel, thanks, whims, fragmenting, recite, mingled,
# Nearest to four: five, two, zero, three, one, six, years, seven,
# Nearest to all: spiritual, barn, disclaimed, cosa, god, few, saraswati, aeons,
# Nearest to five: four, two, seven, zero, six, one, three, july,
# Nearest to known: sabres, sect, characterises, pork, glorioso, tema, elmo, hanged,
# Nearest to will: timed, intensional, that, palettes, privatisation, afternoon, myself, exodus,
# Nearest to for: compulsion, fifa, bloemfontein, endorsed, boac, opal, quartile, incompatible,
# Nearest to other: most, beans, walnuts, means, undigested, panes, for, cormorants,
# Nearest to egypt: barbarians, discernment, ojibwe, balearic, rossellini, trench, syria, persepolis,
# Nearest to san: diego, metohija, panorama, swann, amtrak, melvin, zeeuws, dietmar,
# Nearest to event: imagining, mow, aros, porsche, situational, faerie, jennifer, eldorado,
# Nearest to defense: publicised, warheads, tribunals, caray, attorneys, begining, pullback, saigon,
# Nearest to account: inheriting, habitual, blackmailed, transfiguration, apollonia, pallium, gpmg, panini,
# Nearest to report: quarterly, oecd, connelly, munitions, cai, august, authorities, summits,
# Nearest to shows: hangover, nigra, hulk, daniel, cincinnati, authenticity, dwyer, gemologists,
# Nearest to know: my, you, sure, tell, disoriented, faithfully, airplay, nuances,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0190 0.2603 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0311 0.2647 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0600 0.2608 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0475 0.2557 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0757 0.2599 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0594 0.2584 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0540 0.2592 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1088 0.2578 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0619 0.2600 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0600 0.2459 sec/batch
# Nearest to this: be, tub, cancel, thanks, whims, fragmenting, lysenkoism, cryptosystems,
# Nearest to four: five, two, zero, three, one, six, eight, seven,
# Nearest to all: spiritual, barn, disclaimed, cosa, god, is, few, payment,
# Nearest to five: four, two, seven, zero, six, one, three, eight,
# Nearest to known: sabres, characterises, tema, sect, recreating, acyclic, edwin, spirals,
# Nearest to will: intensional, timed, that, palettes, exodus, me, myself, privatisation,
# Nearest to for: compulsion, algorithmic, definiteness, the, other, fifa, quartile, endorsed,
# Nearest to other: most, for, undigested, means, beans, walnuts, panes, organisms,
# Nearest to egypt: barbarians, ojibwe, balearic, trench, discernment, two, ghazni, hereford,
# Nearest to san: diego, metohija, amtrak, panorama, swann, qualifiers, partying, boatner,
# Nearest to event: imagining, mow, aros, situational, exposures, faerie, jennifer, porsche,
# Nearest to defense: publicised, warheads, caray, tribunals, begining, attorneys, shortcuts, saigon,
# Nearest to account: inheriting, habitual, blackmailed, transfiguration, pallium, apollonia, gpmg, panini,
# Nearest to report: quarterly, oecd, connelly, munitions, www, authorities, summits, mcdougall,
# Nearest to shows: hangover, nigra, cincinnati, hulk, interpolated, daniel, addressable, dhamma,
# Nearest to know: my, you, sure, tell, disoriented, faithfully, airplay, things,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0563 0.2500 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0852 0.2443 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0621 0.2464 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.1007 0.2436 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0933 0.2451 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0560 0.2455 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0568 0.2471 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0404 0.2456 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0862 0.2479 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0795 0.2455 sec/batch
# Nearest to this: be, thanks, whims, lysenkoism, mingled, sidetracked, cancel, tub,
# Nearest to four: five, two, zero, three, one, six, eight, seven,
# Nearest to all: spiritual, disclaimed, barn, payment, god, louisiane, cosa, few,
# Nearest to five: four, two, seven, zero, six, one, three, nine,
# Nearest to known: sabres, tema, sect, glorioso, pork, recreating, characterises, kurdistan,
# Nearest to will: intensional, timed, palettes, that, exodus, me, myself, afternoon,
# Nearest to for: endorsed, compulsion, other, fifa, quartile, definiteness, incompatible, bloemfontein,
# Nearest to other: most, for, beans, rallying, undigested, exalt, panes, means,
# Nearest to egypt: barbarians, discernment, trench, ojibwe, two, ghazni, balearic, unspecified,
# Nearest to san: diego, metohija, panorama, swann, melvin, partying, boatner, zeeuws,
# Nearest to event: imagining, mow, aros, faerie, jennifer, tough, situational, porsche,
# Nearest to defense: publicised, warheads, caray, attorneys, begining, shortcuts, tribunals, saigon,
# Nearest to account: inheriting, habitual, apollonia, transfiguration, pallium, blackmailed, gpmg, persist,
# Nearest to report: quarterly, connelly, oecd, www, mcdougall, summits, authorities, munitions,
# Nearest to shows: hangover, nigra, interpolated, daniel, cincinnati, dhamma, addressable, hulk,
# Nearest to know: my, you, tell, sure, disoriented, faithfully, things, nuances,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0445 0.2457 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0307 0.2429 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0202 0.2422 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0615 0.2455 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0754 0.2453 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1263 0.2488 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1176 0.2721 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0387 0.2601 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0093 0.2847 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0527 0.2850 sec/batch
# Nearest to this: be, thanks, tub, seria, fragmenting, whims, lysenkoism, cancel,
# Nearest to four: five, two, zero, three, one, six, eight, seven,
# Nearest to all: disclaimed, spiritual, barn, god, payment, chupacabra, cosa, few,
# Nearest to five: four, two, seven, zero, six, one, three, eight,
# Nearest to known: sabres, tema, sect, recreating, glorioso, edwin, kublai, budd,
# Nearest to will: intensional, timed, palettes, that, exodus, me, privatisation, myself,
# Nearest to for: compulsion, endorsed, quartile, fifa, other, definiteness, the, developers,
# Nearest to other: most, beans, rallying, for, undigested, walnuts, purged, headings,
# Nearest to egypt: barbarians, discernment, trench, ghazni, two, ojibwe, rossellini, balearic,
# Nearest to san: diego, metohija, partying, feeding, panorama, swann, agnes, santa,
# Nearest to event: imagining, jennifer, mow, aros, faerie, recreate, exposures, terribly,
# Nearest to defense: publicised, warheads, tribunals, caray, disputes, pullback, attorneys, saigon,
# Nearest to account: inheriting, transfiguration, habitual, apollonia, blackmailed, pallium, persist, gpmg,
# Nearest to report: quarterly, oecd, connelly, www, summits, august, authorities, stauffenberg,
# Nearest to shows: hangover, daniel, cincinnati, nigra, hulk, dhamma, interpolated, wikis,
# Nearest to know: my, you, tell, sure, disoriented, faithfully, things, impolite,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0010 0.2927 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0131 0.2931 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0328 0.2921 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0236 0.2928 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0877 0.2970 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0249 0.2614 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0255 0.2992 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9900 0.2951 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0114 0.2940 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9826 0.2970 sec/batch
# Nearest to this: be, thanks, tub, whims, seria, lysenkoism, cancel, authenticate,
# Nearest to four: five, two, zero, three, one, six, eight, nine,
# Nearest to all: spiritual, disclaimed, god, barn, chupacabra, few, cosa, saraswati,
# Nearest to five: four, two, zero, seven, six, one, three, eight,
# Nearest to known: sabres, sect, tema, recreating, kublai, glorioso, pork, edwin,
# Nearest to will: timed, intensional, palettes, exodus, that, me, myself, privatisation,
# Nearest to for: compulsion, quartile, midcourse, other, endorsed, bloemfontein, definiteness, the,
# Nearest to other: most, beans, for, rallying, headings, exalt, panes, means,
# Nearest to egypt: discernment, barbarians, ojibwe, trench, two, ghazni, unspecified, rossellini,
# Nearest to san: diego, metohija, boatner, partying, amtrak, francisco, feeding, bajaj,
# Nearest to event: mow, imagining, jennifer, exposures, aros, faerie, quadrennial, contenders,
# Nearest to defense: publicised, warheads, tribunals, caray, pullback, peacetime, saigon, attorneys,
# Nearest to account: inheriting, habitual, transfiguration, blackmailed, pallium, apollonia, gpmg, panini,
# Nearest to report: quarterly, connelly, oecd, www, mcdougall, mitigation, cai, reins,
# Nearest to shows: hangover, nigra, daniel, dhamma, cincinnati, hulk, authenticity, wikis,
# Nearest to know: my, you, tell, sure, disoriented, faithfully, saying, impolite,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9911 0.3062 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9258 0.2999 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9986 0.3011 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0386 0.3076 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9962 0.3240 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0047 0.3078 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9125 0.3095 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9661 0.3142 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9542 0.3058 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9902 0.3070 sec/batch
# Nearest to this: be, thanks, sidetracked, tub, authenticate, whims, seria, has,
# Nearest to four: five, two, zero, three, one, six, eight, nine,
# Nearest to all: disclaimed, spiritual, god, barn, few, chupacabra, kingssonar, payment,
# Nearest to five: four, two, seven, zero, six, one, three, eight,
# Nearest to known: sabres, sect, tema, kublai, name, pork, manatee, transformations,
# Nearest to will: timed, intensional, palettes, exodus, that, me, shellfish, down,
# Nearest to for: the, compulsion, quartile, fifa, number, other, as, midcourse,
# Nearest to other: most, beans, walnuts, for, panes, means, headings, dispersed,
# Nearest to egypt: ojibwe, barbarians, discernment, ghazni, trench, josiah, unspecified, rossellini,
# Nearest to san: diego, metohija, francisco, santa, boatner, feeding, orozco, psoe,
# Nearest to event: imagining, mow, jennifer, exposures, aros, tegmark, quadrennial, continually,
# Nearest to defense: warheads, publicised, caray, saigon, tribunals, pullback, peacetime, begining,
# Nearest to account: inheriting, habitual, transfiguration, pallium, blackmailed, tous, gpmg, apollonia,
# Nearest to report: quarterly, connelly, oecd, www, mcdougall, august, hearne, cai,
# Nearest to shows: hangover, nigra, daniel, cincinnati, dhamma, authenticity, interpolated, wikis,
# Nearest to know: my, you, tell, sure, disoriented, faithfully, impolite, things,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0146 0.3145 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0053 0.3104 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9305 0.3123 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0381 0.3133 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9853 0.3174 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9863 0.3192 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0162 0.3195 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0219 0.3193 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0033 0.2969 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0018 0.3208 sec/batch
# Nearest to this: be, thanks, has, the, lysenkoism, sidetracked, seria, purfling,
# Nearest to four: five, two, three, zero, one, six, eight, nine,
# Nearest to all: god, disclaimed, spiritual, barn, is, few, chupacabra, payment,
# Nearest to five: four, two, seven, zero, six, one, three, eight,
# Nearest to known: tema, sabres, recreating, transformations, sect, glorioso, budd, spirals,
# Nearest to will: intensional, timed, exodus, palettes, me, that, replied, down,
# Nearest to for: the, compulsion, quartile, as, ntfs, other, endorsed, fifa,
# Nearest to other: most, for, beans, headings, rallying, panes, exalt, means,
# Nearest to egypt: discernment, trench, ghazni, ojibwe, unspecified, barbarians, balearic, two,
# Nearest to san: diego, metohija, francisco, santa, boatner, zeeuws, feeding, psoe,
# Nearest to event: imagining, mow, tegmark, exposures, aros, continually, redefined, jennifer,
# Nearest to defense: warheads, publicised, caray, pullback, tribunals, saigon, peacetime, begining,
# Nearest to account: inheriting, transfiguration, habitual, pallium, tous, persist, blackmailed, gpmg,
# Nearest to report: quarterly, connelly, oecd, www, mcdougall, mitigation, summits, august,
# Nearest to shows: daniel, nigra, hangover, cincinnati, dhamma, interpolated, wikis, authenticity,
# Nearest to know: my, you, tell, sure, things, disoriented, impolite, faithfully,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9699 0.3244 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9938 0.3238 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9696 0.3277 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0151 0.3258 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0004 0.3272 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0033 0.3285 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9654 0.3246 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9334 0.3251 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9665 0.3279 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0211 0.3286 sec/batch
# Nearest to this: be, thanks, has, purfling, the, authenticate, by, lysenkoism,
# Nearest to four: five, two, three, zero, one, six, eight, nine,
# Nearest to all: god, disclaimed, barn, spiritual, chupacabra, is, few, cosa,
# Nearest to five: four, two, seven, zero, six, three, one, eight,
# Nearest to known: tema, glorioso, sect, name, kurdistan, transformations, manatee, recreating,
# Nearest to will: intensional, timed, exodus, palettes, me, that, replied, myself,
# Nearest to for: the, other, as, ntfs, endorsed, compulsion, to, in,
# Nearest to other: most, for, headings, beans, exalt, rallying, purged, dispersed,
# Nearest to egypt: discernment, ghazni, unspecified, ojibwe, trench, two, barbarians, rossellini,
# Nearest to san: diego, metohija, francisco, santa, boatner, feeding, zeeuws, psoe,
# Nearest to event: imagining, mow, extinction, exposures, tegmark, continually, redefined, quadrennial,
# Nearest to defense: publicised, warheads, tribunals, saigon, pullback, peacetime, attorneys, caray,
# Nearest to account: inheriting, transfiguration, pallium, habitual, tous, persist, multiplexing, apollonia,
# Nearest to report: quarterly, oecd, connelly, www, mitigation, mcdougall, stauffenberg, panel,
# Nearest to shows: daniel, cincinnati, dhamma, hangover, nigra, wikis, coanda, interpolated,
# Nearest to know: my, you, tell, sure, disoriented, things, faithfully, impolite,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9797 0.3358 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0708 0.3302 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0385 0.3291 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0493 0.3269 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9308 0.3315 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9583 0.3338 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9963 0.3339 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9230 0.3435 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.0047 0.3421 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9524 0.3433 sec/batch
# Nearest to this: be, thanks, purfling, has, the, authenticate, hohmann, popov,
# Nearest to four: five, two, three, zero, one, six, nine, eight,
# Nearest to all: god, disclaimed, spiritual, barn, chupacabra, few, is, cosa,
# Nearest to five: four, seven, two, six, zero, one, three, eight,
# Nearest to known: tema, glorioso, recreating, sect, budd, sabres, kublai, name,
# Nearest to will: intensional, timed, palettes, exodus, me, replied, that, privatisation,
# ...
# Nearest to know: my, tell, things, you, sure, disoriented, ask, believed,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8603 0.2834 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7348 0.2794 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8170 0.2815 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8067 0.2774 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7896 0.2762 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8515 0.2797 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8954 0.2764 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8307 0.2780 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8452 0.2743 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9048 0.2764 sec/batch
# Nearest to this: the, be, in, has, it, of, since, and,
# Nearest to four: five, two, three, one, zero, six, seven, eight,
# Nearest to all: is, disclaimed, are, and, only, who, this, quinquatria,
# Nearest to five: four, two, seven, six, zero, three, one, eight,
# Nearest to known: many, kublai, is, for, as, to, orthonormal, name,
# Nearest to will: me, intensional, effendi, that, timed, higher, fertilized, palettes,
# Nearest to for: the, in, and, as, of, to, is, other,
# Nearest to other: most, for, many, of, in, can, the, and,
# Nearest to egypt: discernment, monticello, isis, rossellini, kipling, unspecified, egyptians, alexandria,
# Nearest to san: diego, francisco, santa, los, california, angeles, feeding, jose,
# Nearest to event: events, extinction, bolide, paleocene, quadrennial, hotel, terribly, tegmark,
# Nearest to defense: warheads, cornerback, cleavage, offense, rumsfeld, pullback, alligator, arm,
# Nearest to account: inheriting, tous, transfiguration, blackmailed, brasenose, gleaned, apollonia, multiplexing,
# Nearest to report: panel, connelly, mitigation, reports, www, quarterly, oecd, reported,
# Nearest to shows: daniel, instructs, movie, cincinnati, wikis, quadrants, calculated, technicolor,
# Nearest to know: tell, things, my, sure, you, disoriented, believed, ask,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8243 0.2885 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8243 0.2778 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8603 0.2771 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8627 0.2757 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8400 0.2735 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8712 0.2781 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8701 0.2818 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8418 0.2804 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8682 0.2810 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8283 0.2826 sec/batch
# Nearest to this: the, be, of, in, has, and, since, a,
# Nearest to four: five, two, three, one, zero, six, seven, nine,
# Nearest to all: disclaimed, is, and, are, only, quinquatria, fully, who,
# Nearest to five: four, two, seven, six, zero, one, three, eight,
# Nearest to known: many, kublai, name, as, for, is, to, the,
# Nearest to will: me, intensional, effendi, timed, fertilized, that, shellfish, myself,
# Nearest to for: the, in, as, and, to, of, other, is,
# Nearest to other: most, for, many, of, the, and, viking, to,
# Nearest to egypt: discernment, monticello, unspecified, isis, rossellini, egyptians, omar, kipling,
# Nearest to san: diego, francisco, santa, california, los, feeding, angeles, metohija,
# Nearest to event: events, extinction, paleocene, tegmark, bolide, quadrennial, hotel, continually,
# Nearest to defense: warheads, cornerback, cleavage, offense, pullback, rumsfeld, alligator, tba,
# Nearest to account: inheriting, tous, brasenose, transfiguration, apollonia, gleaned, blackmailed, multiplexing,
# Nearest to report: panel, connelly, reported, reports, mitigation, www, oecd, quarterly,
# Nearest to shows: daniel, instructs, cincinnati, wikis, movie, favourably, quadrants, calculated,
# Nearest to know: tell, things, you, sure, my, disoriented, your, we,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8760 0.2832 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8495 0.2813 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8238 0.2810 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8437 0.2800 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8756 0.2849 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8554 0.2927 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9664 0.2837 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8889 0.2826 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9185 0.2808 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8057 0.2809 sec/batch
# Nearest to this: the, has, be, since, of, on, thanks, in,
# Nearest to four: five, two, three, one, zero, six, seven, nine,
# Nearest to all: disclaimed, are, is, and, only, quinquatria, fully, have,
# Nearest to five: four, two, seven, zero, six, three, one, eight,
# Nearest to known: many, is, kublai, name, as, for, orthonormal, of,
# Nearest to will: me, intensional, effendi, that, saying, timed, fertilized, shellfish,
# Nearest to for: the, in, and, as, to, of, other, a,
# Nearest to other: most, for, of, and, the, to, many, in,
# Nearest to egypt: discernment, monticello, unspecified, egyptians, rossellini, isis, dub, omar,
# Nearest to san: diego, francisco, santa, los, california, feeding, angeles, metohija,
# Nearest to event: events, extinction, paleocene, bolide, lucien, sayle, tegmark, terribly,
# Nearest to defense: warheads, cornerback, cleavage, pullback, offense, rumsfeld, arm, alligator,
# Nearest to account: inheriting, tous, apollonia, multiplexing, transfiguration, brasenose, pallium, gleaned,
# Nearest to report: panel, reports, connelly, reported, quarterly, www, mitigation, oecd,
# Nearest to shows: daniel, instructs, cincinnati, wikis, movie, quadrants, favourably, coanda,
# Nearest to know: tell, my, you, things, sure, disoriented, your, ask,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7978 0.2818 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8900 0.2803 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7667 0.2840 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8630 0.2818 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8540 0.2845 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8295 0.2811 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9139 0.1350 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8033 0.2818 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8466 0.2801 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8234 0.2833 sec/batch
# Nearest to this: the, has, be, since, in, and, of, it,
# Nearest to four: five, one, two, three, zero, six, seven, eight,
# Nearest to all: disclaimed, is, and, are, fully, quinquatria, only, who,
# Nearest to five: four, seven, two, six, zero, one, three, eight,
# Nearest to known: many, is, name, of, kublai, to, as, for,
# Nearest to will: me, intensional, effendi, that, saying, timed, you, shellfish,
# Nearest to for: the, in, and, as, to, other, is, of,
# Nearest to other: most, for, of, and, many, in, to, the,
# Nearest to egypt: discernment, monticello, egyptians, isis, rossellini, cheops, unspecified, dub,
# Nearest to san: diego, francisco, santa, los, california, metohija, angeles, psoe,
# Nearest to event: events, extinction, terribly, paleocene, sayle, hotel, tegmark, bolide,
# Nearest to defense: warheads, cornerback, cleavage, offense, pullback, arm, rumsfeld, tackles,
# Nearest to account: inheriting, tous, apollonia, blackmailed, transfiguration, gleaned, pallium, brasenose,
# Nearest to report: panel, connelly, reports, reported, www, quarterly, mitigation, forthcoming,
# Nearest to shows: daniel, instructs, wikis, cincinnati, movie, authenticity, shaker, favourably,
# Nearest to know: tell, things, my, you, sure, disoriented, ask, your,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8421 0.2807 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8227 0.2821 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8247 0.2815 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7799 0.2800 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8485 0.2782 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8296 0.2779 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8516 0.2761 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7612 0.2769 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8108 0.2789 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8176 0.2776 sec/batch
# Nearest to this: the, of, be, has, it, since, in, and,
# Nearest to four: five, two, one, three, zero, six, seven, eight,
# Nearest to all: is, and, are, disclaimed, only, of, fully, which,
# Nearest to five: four, seven, two, six, zero, one, three, eight,
# Nearest to known: many, is, as, name, to, the, kublai, such,
# Nearest to will: me, intensional, that, you, effendi, shellfish, saying, to,
# Nearest to for: the, in, and, of, as, to, is, a,
# Nearest to other: most, of, for, in, and, to, many, the,
# Nearest to egypt: discernment, egyptians, monticello, isis, cheops, rossellini, alexandria, dub,
# Nearest to san: diego, francisco, santa, los, california, jose, angeles, metohija,
# Nearest to event: events, extinction, paleocene, bolide, splendour, quadrennial, cosmological, tegmark,
# Nearest to defense: warheads, cornerback, pullback, cleavage, arm, offense, rumsfeld, apfa,
# Nearest to account: inheriting, apollonia, tous, transfiguration, blackmailed, gleaned, pallium, multiplexing,
# Nearest to report: panel, reports, connelly, www, reported, oecd, quarterly, mitigation,
# Nearest to shows: daniel, instructs, movie, wikis, cincinnati, authenticity, calculated, coanda,
# Nearest to know: you, tell, sure, things, my, ask, disoriented, your,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7718 0.2814 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8087 0.2767 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8877 0.2795 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8032 0.2784 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7985 0.2787 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8866 0.2797 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8403 0.2858 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8326 0.2772 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8161 0.2792 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8383 0.2780 sec/batch
# Nearest to this: the, of, be, has, in, since, it, a,
# Nearest to four: five, two, three, one, zero, six, seven, eight,
# Nearest to all: are, and, is, only, fully, disclaimed, this, of,
# Nearest to five: four, two, seven, zero, six, one, three, eight,
# Nearest to known: many, is, name, as, to, for, such, the,
# Nearest to will: me, intensional, effendi, that, you, shellfish, gift, tangenziale,
# Nearest to for: the, in, and, of, as, to, a, other,
# Nearest to other: most, of, for, in, and, the, has, to,
# Nearest to egypt: discernment, egyptians, monticello, suez, alexandria, omar, isis, dflp,
# Nearest to san: diego, francisco, santa, los, california, angeles, jose, metohija,
# Nearest to event: events, extinction, paleocene, bolide, cosmological, splendour, jurassic, tegmark,
# Nearest to defense: cornerback, warheads, offense, cleavage, pullback, arm, rumsfeld, apfa,
# Nearest to account: inheriting, apollonia, tous, transfiguration, multiplexing, pallium, brasenose, blackmailed,
# Nearest to report: panel, reports, connelly, www, mitigation, quarterly, reported, oecd,
# Nearest to shows: daniel, instructs, wikis, cincinnati, movie, authenticity, technicolor, shown,
# Nearest to know: things, sure, tell, you, my, ask, disoriented, your,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8748 0.2826 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8246 0.2791 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8307 0.2790 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8509 0.2819 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8775 0.2789 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8179 0.2809 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8379 0.2817 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8425 0.2798 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8040 0.2807 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8170 0.2772 sec/batch
# Nearest to this: the, of, in, and, a, be, has, by,
# Nearest to four: five, two, three, one, zero, six, seven, nine,
# Nearest to all: and, are, is, only, of, which, few, this,
# Nearest to five: four, two, seven, six, zero, three, one, eight,
# Nearest to known: many, is, the, as, in, name, of, to,
# Nearest to will: me, intensional, that, effendi, you, fertilized, shellfish, isn,
# Nearest to for: the, in, and, as, of, to, other, a,
# Nearest to other: most, of, and, for, in, to, the, many,
# Nearest to egypt: discernment, egyptians, monticello, suez, omar, isis, kipling, rossellini,
# Nearest to san: diego, francisco, santa, los, california, angeles, jose, degli,
# Nearest to event: events, extinction, paleocene, bolide, splendour, paleozoic, cosmological, quadrennial,
# Nearest to defense: warheads, cornerback, offense, pullback, cleavage, arm, rumsfeld, apfa,
# Nearest to account: inheriting, tous, apollonia, transfiguration, persist, gleaned, multiplexing, brasenose,
# Nearest to report: panel, reports, connelly, www, quarterly, mitigation, reported, mideast,
# Nearest to shows: daniel, instructs, wikis, cincinnati, shown, favourably, quadrants, authenticity,
# Nearest to know: tell, sure, things, ask, you, disoriented, my, your,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8754 0.2848 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8235 0.2861 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9297 0.2814 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8987 0.2829 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8728 0.2826 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8348 0.2841 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7712 0.2790 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8179 0.2801 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7252 0.2794 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8518 0.2823 sec/batch
# Nearest to this: the, has, of, a, since, be, on, is,
# Nearest to four: five, two, three, one, zero, six, seven, nine,
# Nearest to all: and, are, is, only, few, of, this, fully,
# Nearest to five: four, two, seven, six, zero, one, three, eight,
# Nearest to known: many, is, as, to, name, of, the, for,
# Nearest to will: me, intensional, effendi, that, you, fertilized, shellfish, hyenas,
# Nearest to for: the, in, as, and, of, other, to, a,
# Nearest to other: most, of, for, and, in, to, many, the,
# Nearest to egypt: egyptians, discernment, monticello, suez, rossellini, isis, omar, cheops,
# Nearest to san: diego, francisco, santa, los, california, jose, angeles, psoe,
# Nearest to event: events, extinction, paleocene, splendour, bolide, sayle, quadrennial, jurassic,
# Nearest to defense: warheads, cornerback, cleavage, offense, pullback, arm, protective, aquila,
# Nearest to account: inheriting, tous, multiplexing, brasenose, apollonia, transfiguration, gleaned, pallium,
# Nearest to report: reports, panel, connelly, www, quarterly, reported, mitigation, mideast,
# Nearest to shows: daniel, movie, cincinnati, wikis, instructs, costello, quadrants, authenticity,
# Nearest to know: sure, tell, ask, things, disoriented, you, your, what,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8471 0.2856 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8460 0.2785 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
